# %% [markdown]
# <a href="https://colab.research.google.com/github/dhrubo-018/AI_Projects/blob/master/Covid19_Outbreak_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import io

# %%
google_mobility_data = pd.read_csv('https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
us_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv')

# %%
us_confirmed.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 4/14/22  4/15/22  4/16/22  4/17/22  4/18/22  \
# 0  32.539527 -86.644082  ...   15751    15752    15752    15752    15771
# 1  30.727750 -87.722071  ...   55536    55547    55547    55547    55579
# 2  31.868263 -85.387129  ...    5658     5658     5658     5658     5659
# 3  32.996421 -87.125115  ...    6428     6428     6428     6428     6428
# 4  33.982109 -86.567906  ...   14953    14959    14959    14959    14963
#
#    4/19/22  4/20/22  4/21/22  4/22/22  4/23/22
# ...

# %%
us_confirmed.describe()
# Out:
#                 UID        code3          FIPS          Lat        Long_  \
# count  3.342000e+03  3342.000000   3332.000000  3342.000000  3342.000000
# mean   8.342992e+07   834.494913  33043.078932    36.721617   -88.642045
# std    4.314076e+06    36.487378  18648.808931     9.079322    21.776287
# min    1.600000e+01    16.000000     60.000000   -14.271000  -174.159600
# 25%    8.401811e+07   840.000000  19076.500000    33.896803   -97.803595
# 50%    8.402921e+07   840.000000  31012.000000    38.005610   -89.488865
# 75%    8.404612e+07   840.000000  47129.500000    41.579255   -82.313398
# max    8.410000e+07   850.000000  99999.000000    69.314792   145.673900
#
#            1/22/20      1/23/20      1/24/20      1/25/20      1/26/20  ...  \
# count  3342.000000  3342.000000  3342.000000  3342.000000  3342.000000  ...
# mean      0.000299     0.000299     0.000598     0.000598     0.001496  ...
# std       0.017298     0.017298     0.024459     0.024459     0.038656  ...
# ...

# %%
columns = us_confirmed.keys()
#new_york_confimed = us_confirmed.loc[us_confirmed[columns[6]] == 'New York']
new_york_confimed = us_confirmed.loc[us_confirmed['Province_State'] == 'New York']
new_york_confimed.head()
# Out:
#            UID iso2 iso3  code3     FIPS       Admin2 Province_State  \
# 1902  84036001   US  USA    840  36001.0       Albany       New York
# 1903  84036003   US  USA    840  36003.0     Allegany       New York
# 1904  84036005   US  USA    840  36005.0        Bronx       New York
# 1905  84036007   US  USA    840  36007.0       Broome       New York
# 1906  84036009   US  USA    840  36009.0  Cattaraugus       New York
#
#      Country_Region        Lat      Long_  ... 4/14/22  4/15/22  4/16/22  \
# 1902             US  42.600603 -73.977239  ...   59676    59804    59912
# 1903             US  42.257484 -78.027505  ...    8966     8972     8984
# 1904             US  40.852093 -73.862828  ...  409074   409312   409312
# 1905             US  42.159032 -75.813261  ...   46075    46194    46320
# 1906             US  42.247782 -78.679231  ...   15510    15521    15535
#
#       4/17/22  4/18/22  4/19/22  4/20/22  4/21/22  4/22/22  4/23/22
# ...

# %%
new_york_confimed_dates = new_york_confimed.iloc[:,41:-1]
dates = new_york_confimed_dates.keys()
new_york_daily_cases = new_york_confimed_dates.diff(axis=1)
new_york_daily_cases = new_york_daily_cases.iloc[:,1:-2]
# pd.concat([df1, df4], axis=1)
df = pd.concat([new_york_confimed['Admin2'],new_york_daily_cases], axis=1)
# new_york_confimed['Admin2'].reset_index()
df = df.reset_index()
# df.drop(['B', 'C'], axis=1)
df.drop(['index'],axis=1,inplace= True)
new_york_daily_cases = df
# new_york_daily_cases = new_york_confimed_dates.iloc[:,1:-1]
new_york_daily_cases
# new_york_daily_cases = new_york_confimed['Admin2'] + new_york_daily_cases
# Out:
#          Admin2  2/22/20  2/23/20  2/24/20  2/25/20  2/26/20  2/27/20  \
# 0        Albany        0        0        0        0        0        0
# 1      Allegany        0        0        0        0        0        0
# 2         Bronx        0        0        0        0        0        0
# 3        Broome        0        0        0        0        0        0
# 4   Cattaraugus        0        0        0        0        0        0
# ..          ...      ...      ...      ...      ...      ...      ...
# 59   Washington        0        0        0        0        0        0
# 60        Wayne        0        0        0        0        0        0
# 61  Westchester        0        0        0        0        0        0
# 62      Wyoming        0        0        0        0        0        0
# 63        Yates        0        0        0        0        0        0
#
#     2/28/20  2/29/20  3/1/20  ...  4/11/22  4/12/22  4/13/22  4/14/22  \
# ...

# %%
values = ['Hamilton', 'Out of NY','Unassigned']
# new_york_daily_cases.drop(new_york_daily_cases.Admin2.isin(values) == 'Unassigned', axis = 0, inplace=True)
new_york_daily_cases = new_york_daily_cases[new_york_daily_cases.Admin2.isin(values) == False]
new_york_daily_cases
# Out:
#          Admin2  2/22/20  2/23/20  2/24/20  2/25/20  2/26/20  2/27/20  \
# 0        Albany        0        0        0        0        0        0
# 1      Allegany        0        0        0        0        0        0
# 2         Bronx        0        0        0        0        0        0
# 3        Broome        0        0        0        0        0        0
# 4   Cattaraugus        0        0        0        0        0        0
# ..          ...      ...      ...      ...      ...      ...      ...
# 59   Washington        0        0        0        0        0        0
# 60        Wayne        0        0        0        0        0        0
# 61  Westchester        0        0        0        0        0        0
# 62      Wyoming        0        0        0        0        0        0
# 63        Yates        0        0        0        0        0        0
#
#     2/28/20  2/29/20  3/1/20  ...  4/11/22  4/12/22  4/13/22  4/14/22  \
# ...

# %%
new_york_daily_cases = new_york_daily_cases.T

# %%
new_york_daily_cases
# Out:
#              0         1      2       3            4       5           6   \
# Admin2   Albany  Allegany  Bronx  Broome  Cattaraugus  Cayuga  Chautauqua
# 2/22/20       0         0      0       0            0       0           0
# 2/23/20       0         0      0       0            0       0           0
# 2/24/20       0         0      0       0            0       0           0
# 2/25/20       0         0      0       0            0       0           0
# ...         ...       ...    ...     ...          ...     ...         ...
# 4/16/22     108        12      0     126           14      25          21
# 4/17/22       0         0      0       0            0       0           0
# 4/18/22     154         4    608     156           17      47          18
# 4/19/22      63        11    176      50            9      16          14
# 4/20/22     118         5    290     129           25      35          12
#
#               7         8        9   ...        53     54        55      56  \
# ...

# %%
mobility_data_NY = google_mobility_data[google_mobility_data['sub_region_1'] == 'New York']
mobility_data_NY.head(-5)
# Out:
#         country_region_code country_region sub_region_1  sub_region_2  \
# 8623413                  US  United States     New York           NaN
# 8623414                  US  United States     New York           NaN
# 8623415                  US  United States     New York           NaN
# 8623416                  US  United States     New York           NaN
# 8623417                  US  United States     New York           NaN
# ...                     ...            ...          ...           ...
# 8672493                  US  United States     New York  Yates County
# 8672494                  US  United States     New York  Yates County
# 8672495                  US  United States     New York  Yates County
# 8672496                  US  United States     New York  Yates County
# 8672497                  US  United States     New York  Yates County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 8623413        NaN           US-NY               NaN
# ...

# %%
mobility_data_NY.sub_region_2.unique()
# Out:
# array([nan, 'Albany County', 'Allegany County', 'Bronx County',
#        'Broome County', 'Cattaraugus County', 'Cayuga County',
#        'Chautauqua County', 'Chemung County', 'Chenango County',
#        'Clinton County', 'Columbia County', 'Cortland County',
#        'Delaware County', 'Dutchess County', 'Erie County',
#        'Essex County', 'Franklin County', 'Fulton County',
#        'Genesee County', 'Greene County', 'Herkimer County',
#        'Jefferson County', 'Kings County', 'Lewis County',
#        'Livingston County', 'Madison County', 'Monroe County',
#        'Montgomery County', 'Nassau County', 'New York County',
#        'Niagara County', 'Oneida County', 'Onondaga County',
#        'Ontario County', 'Orange County', 'Orleans County',
#        'Oswego County', 'Otsego County', 'Putnam County', 'Queens County',
#        'Rensselaer County', 'Richmond County', 'Rockland County',
#        'Saratoga County', 'Schenectady County', 'Schoharie County',
# ...

# %%
mobility_data_NY
# Out:
#         country_region_code country_region sub_region_1  sub_region_2  \
# 8623413                  US  United States     New York           NaN
# 8623414                  US  United States     New York           NaN
# 8623415                  US  United States     New York           NaN
# 8623416                  US  United States     New York           NaN
# 8623417                  US  United States     New York           NaN
# ...                     ...            ...          ...           ...
# 8672498                  US  United States     New York  Yates County
# 8672499                  US  United States     New York  Yates County
# 8672500                  US  United States     New York  Yates County
# 8672501                  US  United States     New York  Yates County
# 8672502                  US  United States     New York  Yates County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 8623413        NaN           US-NY               NaN
# ...

# %%
mobility_data_NY.drop("country_region",axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mobility_data_NY.drop("country_region_code",axis=1,inplace=True)
mobility_data_NY.drop("sub_region_1",axis=1,inplace=True)
mobility_data_NY.drop("iso_3166_2_code",axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mobility_data_NY.drop("census_fips_code",axis=1,inplace=True)
mobility_data_NY.drop("place_id",axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mobility_data_NY
# Out:
#          sub_region_2 metro_area        date  \
# 8623413           NaN        NaN  2020-02-15
# 8623414           NaN        NaN  2020-02-16
# 8623415           NaN        NaN  2020-02-17
# 8623416           NaN        NaN  2020-02-18
# 8623417           NaN        NaN  2020-02-19
# ...               ...        ...         ...
# 8672498  Yates County        NaN  2022-04-16
# 8672499  Yates County        NaN  2022-04-17
# 8672500  Yates County        NaN  2022-04-18
# 8672501  Yates County        NaN  2022-04-19
# 8672502  Yates County        NaN  2022-04-20
#
#          retail_and_recreation_percent_change_from_baseline  \
# 8623413                                                3.0
# 8623414                                                7.0
# 8623415                                                7.0
# 8623416                                               -2.0
# 8623417                                                3.0
# ...                                                    ...
# ...

# %%
mobility_data_NY.rename(columns = {'retail_and_recreation_percent_change_from_baseline':'retail_and_recreation', 'grocery_and_pharmacy_percent_change_from_baseline':'grocery_and_pharmacy',
                              'parks_percent_change_from_baseline':'parks','transit_stations_percent_change_from_baseline':'transit_stations','workplace_percent_change_from_baseline':'workplace','resindentia_percent_change_from_baseline':'residential'}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mobility_data_NY.rename(columns = {'workplaces_percent_change_from_baseline':'workplace','residential_percent_change_from_baseline':'residential'}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mobility_data_NY
# Out:
#          sub_region_2 metro_area        date  retail_and_recreation  \
# 8623413           NaN        NaN  2020-02-15                    3.0
# 8623414           NaN        NaN  2020-02-16                    7.0
# 8623415           NaN        NaN  2020-02-17                    7.0
# 8623416           NaN        NaN  2020-02-18                   -2.0
# 8623417           NaN        NaN  2020-02-19                    3.0
# ...               ...        ...         ...                    ...
# 8672498  Yates County        NaN  2022-04-16                    NaN
# 8672499  Yates County        NaN  2022-04-17                    NaN
# 8672500  Yates County        NaN  2022-04-18                    NaN
# 8672501  Yates County        NaN  2022-04-19                    NaN
# 8672502  Yates County        NaN  2022-04-20                    NaN
#
#          grocery_and_pharmacy  parks  transit_stations  workplace  residential
# ...

# %%
mobility_data_NY.sub_region_2.unique()
# Out:
# array([nan, 'Albany County', 'Allegany County', 'Bronx County',
#        'Broome County', 'Cattaraugus County', 'Cayuga County',
#        'Chautauqua County', 'Chemung County', 'Chenango County',
#        'Clinton County', 'Columbia County', 'Cortland County',
#        'Delaware County', 'Dutchess County', 'Erie County',
#        'Essex County', 'Franklin County', 'Fulton County',
#        'Genesee County', 'Greene County', 'Herkimer County',
#        'Jefferson County', 'Kings County', 'Lewis County',
#        'Livingston County', 'Madison County', 'Monroe County',
#        'Montgomery County', 'Nassau County', 'New York County',
#        'Niagara County', 'Oneida County', 'Onondaga County',
#        'Ontario County', 'Orange County', 'Orleans County',
#        'Oswego County', 'Otsego County', 'Putnam County', 'Queens County',
#        'Rensselaer County', 'Richmond County', 'Rockland County',
#        'Saratoga County', 'Schenectady County', 'Schoharie County',
# ...

# %%
mobility_data_NY = mobility_data_NY[mobility_data_NY.sub_region_2.isnull() == False]

# %%
mobility_data_NY
# Out:
#           sub_region_2 metro_area        date  retail_and_recreation  \
# 8624209  Albany County        NaN  2020-02-15                    8.0
# 8624210  Albany County        NaN  2020-02-16                    7.0
# 8624211  Albany County        NaN  2020-02-17                   11.0
# 8624212  Albany County        NaN  2020-02-18                   -7.0
# 8624213  Albany County        NaN  2020-02-19                    4.0
# ...                ...        ...         ...                    ...
# 8672498   Yates County        NaN  2022-04-16                    NaN
# 8672499   Yates County        NaN  2022-04-17                    NaN
# 8672500   Yates County        NaN  2022-04-18                    NaN
# 8672501   Yates County        NaN  2022-04-19                    NaN
# 8672502   Yates County        NaN  2022-04-20                    NaN
#
#          grocery_and_pharmacy  parks  transit_stations  workplace  residential
# ...

# %%
mobility_data_NY.drop("metro_area",axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
mobility_data_NY
# Out:
#           sub_region_2        date  retail_and_recreation  \
# 8624209  Albany County  2020-02-15                    8.0
# 8624210  Albany County  2020-02-16                    7.0
# 8624211  Albany County  2020-02-17                   11.0
# 8624212  Albany County  2020-02-18                   -7.0
# 8624213  Albany County  2020-02-19                    4.0
# ...                ...         ...                    ...
# 8672498   Yates County  2022-04-16                    NaN
# 8672499   Yates County  2022-04-17                    NaN
# 8672500   Yates County  2022-04-18                    NaN
# 8672501   Yates County  2022-04-19                    NaN
# 8672502   Yates County  2022-04-20                    NaN
#
#          grocery_and_pharmacy  parks  transit_stations  workplace  residential
# 8624209                  -4.0   45.0               4.0        0.0          0.0
# 8624210                  -6.0    8.0              -1.0        2.0         -1.0
# ...

# %%
mobility_data_NY.isnull().sum()
# Out:
# sub_region_2                 0
# date                         0
# retail_and_recreation     3496
# grocery_and_pharmacy      5480
# parks                    31355
# transit_stations         24078
# workplace                  234
# residential               4793
# dtype: int64

# %%
mobility_data_NY.drop("parks",axis=1,inplace=True)
mobility_data_NY.drop("transit_stations",axis=1,inplace=True)
mobility_data_NY
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#           sub_region_2        date  retail_and_recreation  \
# 8624209  Albany County  2020-02-15                    8.0
# 8624210  Albany County  2020-02-16                    7.0
# 8624211  Albany County  2020-02-17                   11.0
# 8624212  Albany County  2020-02-18                   -7.0
# 8624213  Albany County  2020-02-19                    4.0
# ...                ...         ...                    ...
# 8672498   Yates County  2022-04-16                    NaN
# 8672499   Yates County  2022-04-17                    NaN
# 8672500   Yates County  2022-04-18                    NaN
# 8672501   Yates County  2022-04-19                    NaN
# ...

# %%
mobility_data_NY.isnull().values.any()
# Out:
# True

# %%
selected_regions = ['Albany County', 'Bronx County', 'Jefferson County', 'Broome County','Clinton County']

# %%
for reg in selected_regions:
  mobility_data_temp = mobility_data_NY.loc[mobility_data_NY['sub_region_2'] == reg]
  mobility_data_temp = mobility_data_temp.interpolate()
  temp_mob = mobility_data_temp
  temp_mob = temp_mob.iloc[0: -1, :]
  temp_mob.drop(temp_mob.index[0:0], axis=0, inplace=True)
  temp_mob = temp_mob.reset_index()
  temp_mob.drop('index', axis=1, inplace=True) 
  temp_mob = temp_mob.reset_index()
  temp_mob.drop("sub_region_2", axis=1, inplace=True)
  temp_mob.drop("date", axis=1, inplace=True)
  if reg == selected_regions[0]:
    albany_mob_data_temp = temp_mob
  elif reg == selected_regions[1]:
    bronx_mob_data_temp = temp_mob
  elif reg == selected_regions[2]:
    jefferson_mob_data_temp = temp_mob
  elif reg == selected_regions[3]:
    broome_mob_data_temp = temp_mob
  elif reg == selected_regions[4]:
    clinton_mob_data_temp = temp_mob
clinton_mob_data_temp
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      index  retail_and_recreation  grocery_and_pharmacy  workplace  \
# 0        0                    9.0                  -2.0        5.0
# 1        1                   14.0                  10.0        1.0
# 2        2                   15.0                  -1.0      -25.0
# 3        3                   -5.0                  -9.0      -11.0
# 4        4                    2.0                  -6.0      -11.0
# ..     ...                    ...                   ...        ...
# 786    786                    3.0                  17.0      -27.0
# 787    787                   -7.0                  17.0      -14.0
# ...

# %% [markdown]
# # Removing null values from each columns

# %%
mobility_data_NY = mobility_data_NY.interpolate()

# %%
mobility_data_NY.isnull().values.any()
mobility_data_NY.isnull().sum()
# Out:
# sub_region_2             0
# date                     0
# retail_and_recreation    0
# grocery_and_pharmacy     0
# workplace                0
# residential              0
# dtype: int64

# %%
mobility_data_NY
# Out:
#           sub_region_2        date  retail_and_recreation  \
# 8624209  Albany County  2020-02-15                    8.0
# 8624210  Albany County  2020-02-16                    7.0
# 8624211  Albany County  2020-02-17                   11.0
# 8624212  Albany County  2020-02-18                   -7.0
# 8624213  Albany County  2020-02-19                    4.0
# ...                ...         ...                    ...
# 8672498   Yates County  2022-04-16                  -33.0
# 8672499   Yates County  2022-04-17                  -33.0
# 8672500   Yates County  2022-04-18                  -33.0
# 8672501   Yates County  2022-04-19                  -33.0
# 8672502   Yates County  2022-04-20                  -33.0
#
#          grocery_and_pharmacy  workplace  residential
# 8624209             -4.000000        0.0          0.0
# 8624210             -6.000000        2.0         -1.0
# 8624211              2.000000      -41.0          9.0
# ...

# %% [markdown]
# # Taking Albany  data out (both mobility and case data)

# %%
mobility_data_Albany = mobility_data_NY.loc[mobility_data_NY['sub_region_2'] == 'Albany County']

# %%
print(len(mobility_data_Albany))
# Out:
# 796

# %%
mobility_data_Albany
# Out:
#           sub_region_2        date  retail_and_recreation  \
# 8624209  Albany County  2020-02-15                    8.0
# 8624210  Albany County  2020-02-16                    7.0
# 8624211  Albany County  2020-02-17                   11.0
# 8624212  Albany County  2020-02-18                   -7.0
# 8624213  Albany County  2020-02-19                    4.0
# ...                ...         ...                    ...
# 8625000  Albany County  2022-04-16                  -19.0
# 8625001  Albany County  2022-04-17                  -52.0
# 8625002  Albany County  2022-04-18                  -17.0
# 8625003  Albany County  2022-04-19                  -26.0
# 8625004  Albany County  2022-04-20                  -18.0
#
#          grocery_and_pharmacy  workplace  residential
# 8624209                  -4.0        0.0          0.0
# 8624210                  -6.0        2.0         -1.0
# 8624211                   2.0      -41.0          9.0
# ...

# %%
new_york_daily_cases
# Out:
#              0         1      2       3            4       5           6   \
# Admin2   Albany  Allegany  Bronx  Broome  Cattaraugus  Cayuga  Chautauqua
# 2/22/20       0         0      0       0            0       0           0
# 2/23/20       0         0      0       0            0       0           0
# 2/24/20       0         0      0       0            0       0           0
# 2/25/20       0         0      0       0            0       0           0
# ...         ...       ...    ...     ...          ...     ...         ...
# 4/16/22     108        12      0     126           14      25          21
# 4/17/22       0         0      0       0            0       0           0
# 4/18/22     154         4    608     156           17      47          18
# 4/19/22      63        11    176      50            9      16          14
# 4/20/22     118         5    290     129           25      35          12
#
#               7         8        9   ...        53     54        55      56  \
# ...

# %%
temp_d = new_york_daily_cases.T

# %%
# selected_regions_daily = ['Albany', 'Bronx', 'Jefferson', 'Broome','Kings']

# %%
# print(selected_regions[0][:-7])
temp_d
# Out:
#          Admin2 2/22/20 2/23/20 2/24/20 2/25/20 2/26/20 2/27/20 2/28/20  \
# 0        Albany       0       0       0       0       0       0       0
# 1      Allegany       0       0       0       0       0       0       0
# 2         Bronx       0       0       0       0       0       0       0
# 3        Broome       0       0       0       0       0       0       0
# 4   Cattaraugus       0       0       0       0       0       0       0
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 59   Washington       0       0       0       0       0       0       0
# 60        Wayne       0       0       0       0       0       0       0
# 61  Westchester       0       0       0       0       0       0       0
# 62      Wyoming       0       0       0       0       0       0       0
# 63        Yates       0       0       0       0       0       0       0
#
#    2/29/20 3/1/20  ... 4/11/22 4/12/22 4/13/22 4/14/22 4/15/22 4/16/22  \
# ...

# %%
for reg in selected_regions:
  daily_temp = temp_d.loc[temp_d['Admin2'] == reg[:-7]]
  daily_temp = daily_temp.T
  daily_temp = daily_temp.iloc[1: , :]
  daily_temp.drop(daily_temp.index[0:0], axis=0, inplace=True)
  daily_temp.reset_index(drop=True, inplace=True)

  if reg == selected_regions[0]:
    albany_daily_temp = daily_temp
  elif reg == selected_regions[1]:
    bronx_daily_temp = daily_temp
  elif reg == selected_regions[2]:
    jefferson_daily_temp = daily_temp
  elif reg == selected_regions[3]:
    broome_daily_temp = daily_temp
  elif reg == selected_regions[4]:
    clinton_daily_temp = daily_temp
clinton_daily_temp
# Out:
#       9
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ..   ..
# 784  41
# 785   0
# 786  69
# 787  14
# 788  17
#
# [789 rows x 1 columns]

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
X = clinton_mob_data_temp
Y = clinton_daily_temp

X_train = X.iloc[:-14]
X_test = X.iloc[-14:-7]
Y_train = Y.iloc[:-12]
Y_test = Y.iloc[-7:]

sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

reg_clinton = MLPRegressor(hidden_layer_sizes=(256,256,512),activation="relu" ,random_state=1, max_iter=2000).fit(X_trainscaled, Y_train)
Y_pred=reg_clinton.predict(X_testscaled)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
Y_test
# Out:
#       9
# 782  40
# 783  40
# 784  41
# 785   0
# 786  69
# 787  14
# 788  17

# %%
Y_pred
# Out:
# array([18.17392477, 13.32592904, 14.14738258, 13.37817536, 16.2403796 ,
#        16.74138009, 16.64391434])

# %%
X = bronx_mob_data_temp
Y = bronx_daily_temp

X_train = X.iloc[:-14]
X_test = X.iloc[-14:-7]
Y_train = Y.iloc[:-8]
Y_test = Y.iloc[-7:]

sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

reg_bronx = MLPRegressor(hidden_layer_sizes=(256,256,512),activation="relu" ,random_state=1, max_iter=2000).fit(X_trainscaled, Y_train)
Y_pred=reg_bronx.predict(X_testscaled)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
Y_test
# Out:
#        2
# 782  254
# 783  238
# 784    0
# 785    0
# 786  608
# 787  176
# 788  290

# %%
Y_pred
# Out:
# array([294.22291311, 478.28606716, 233.19569508, 260.38606145,
#         25.01269952, 245.89164989, 229.90680671])

# %%
X = broome_mob_data_temp
Y = broome_daily_temp

X_train = X.iloc[:-14]
X_test = X.iloc[-14:-7]
Y_train = Y.iloc[:-8]
Y_test = Y.iloc[-7:]

sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

reg_bronx = MLPRegressor(hidden_layer_sizes=(256,256,512),activation="relu" ,random_state=1, max_iter=2000).fit(X_trainscaled, Y_train)
Y_pred=reg_bronx.predict(X_testscaled)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
Y_test
# Out:
#        3
# 782  223
# 783  119
# 784  126
# 785    0
# 786  156
# 787   50
# 788  129

# %%
Y_test.sum()/5
# Out:
# 3    160.6
# dtype: object

# %%
Y_pred
# Out:
# array([26.04952672, 30.40616192, 22.87410054, 44.54229795, 43.70879606,
#        40.58845013, 83.03518664])

# %%
Y_pred = list(map(abs,Y_pred))
print(sum(Y_pred)/7)
# Out:
# 41.60064570706528

# %%
X = albany_mob_data_temp
Y = albany_daily_temp

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)

# X_train = X.iloc[:-7]
# X_test = X.iloc[-7:]
# Y_train = Y.iloc[:-7]
# Y_test = Y.iloc[-7:]

sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

reg = MLPRegressor(hidden_layer_sizes=(256,256,512),activation="relu" ,random_state=1, max_iter=2000).fit(X_trainscaled, Y_train)
Y_pred=reg.predict(X_testscaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-ae80614cfaf9> in <module>()
#       2 Y = albany_daily_temp
#       3
# ----> 4 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)
#       5
#       6 # X_train = X.iloc[:-7]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# ...

# %%
print("The Score with ", (r2_score(Y_pred, Y_test)))

# %%
albany_daily_cases = temp.loc[temp['Admin2']=='Albany']
albany_daily_cases = albany_daily_cases.T
albany_daily_cases

# %% [markdown]
# **Removing date column from both data set**

# %%
temp = mobility_data_Albany
temp = temp.iloc[0: -1, :]
temp.drop(temp.index[0:0], axis=0, inplace=True)
temp = temp.reset_index()
temp.drop('index', axis=1, inplace=True) 
temp = temp.reset_index()
temp

# %%
temp.drop("sub_region_2", axis=1, inplace=True)
temp.drop("date", axis=1, inplace=True)
temp

# %%
mobility_data_Albany_ready = temp
mobility_data_Albany_ready

# %%
temp = albany_daily_cases
temp = temp.iloc[1: , :]
temp.drop(temp.index[0:0], axis=0, inplace=True)
# temp = temp.reset_index()
# temp.drop('index', axis=1, inplace=True) 
# temp = temp.reset_index()
temp.reset_index(drop=True, inplace=True)
temp

# %%
# temp.rename(columns={'0':'cases'}, inplace=True)
albany_daily_cases_ready = temp
albany_daily_cases_ready

# %% [markdown]
# # Model training

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
# X, y = make_regression(n_samples=200, random_state=1)
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# regr = MLPRegressor(random_state=1, max_iter=500).fit(x, y)

# %%
X = mobility_data_Albany_ready
Y = albany_daily_cases_ready
# neural_net = MLPRegressor(max_iter=100000).fit(x, train_y)

# %%
X_train = X.iloc[:-7]
X_test = X.iloc[-7:]
Y_train = Y.iloc[:-8]
Y_test = Y.iloc[-7:]

# %%
Y_train.shape

# %%
sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

# %%
reg = MLPRegressor(hidden_layer_sizes=(256,256,512),activation="relu" ,random_state=1, max_iter=2000).fit(X_trainscaled, Y_train)

# %%
X_testscaled

# %%
X_testscaled.loc[0]
# bla_bla = 
# print(reg.predict(bla_bla))

# %%
Y_pred=reg.predict(X_testscaled)
print("The Score with ", (r2_score(Y_pred, Y_test)))

# %%
Y_test

# %%
Y_pred

# %%
# data = pd.read_csv(io.BytesIO(uploaded['New york state mobility data.csv']))

# %%
pip install flask-ngrok

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/MyDrive/Colab Notebooks/AI_project_renders"
# Out:
# /content/drive/MyDrive/Colab Notebooks/AI_project_renders

# %%
! pip install pyngrok
! ngrok authtoken 28CgiLxiV3ojyqcPxXCYF94Osxr_3eX55q3peB1XZtHEPXFtq
# Out:
# ...
#      |████████████████████████████████| 745 kB 5.5 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=5de00dd21d107887985d4a63f800b91ee2425b3c0ccb1374ddd8ac0f76aa724d
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
app = Flask(__name__)
run_with_ngrok(app)

@app.route('/', methods=['GET'])
def home():
    return render_template('frontpage.html')

@app.route('/', methods=['GET', "POST"])
def predict():
    return render_template('frontpage.html', predictions="albanyPredicted")

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://2067-34-70-225-102.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [24/Apr/2022 05:06:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2022 05:09:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2022 05:09:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Apr/2022 05:09:12] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [24/Apr/2022 05:20:16] "GET / HTTP/1.1" 200 -
